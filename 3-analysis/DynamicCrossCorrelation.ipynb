# %% [markdown]
# # Dynamic Cross-Correlation Anlysis
#
# DCC across select group of Ampho sponge
# Mycosamine & Tails for now.

# %%
from string import ascii_letters
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

#sns.set_theme(style="white")

# %%
rs = np.loadtxt('/Scr/arango/ergosterol-amb/1-WorkflowDevelopment/3-analysis/scrape_CA/testC22.dat')
print(rs.shape)
# Out:
# (125, 125)

# %%
plt.rcParams["figure.figsize"] = (10,10)


ax = sns.heatmap(rs, vmin=0.0, vmax=1.0, cmap='Spectral')

ax.set_title('DCC: CHL 219', fontdict={'fontsize': 30, 'fontweight': 'medium'})
ax.xaxis.set_major_locator(ticker.MultipleLocator(10))
ax.xaxis.set_major_formatter(ticker.ScalarFormatter())
ax.yaxis.set_major_locator(ticker.MultipleLocator(10))
ax.yaxis.set_major_formatter(ticker.ScalarFormatter())
#sns.heatmap(rs, vmin=0.0, vmax=1.0, cmap='Spectral')
sns.set(font_scale = 2.3)
plt.savefig('CHL219_TEST.png', dpi=600)
plt.show()

# %%
name = "CHL.EPI"

C219 = np.loadtxt('/Scr/arango/ergosterol-amb/1-WorkflowDevelopment/3-analysis/0-DCC/test.CHL.219.dat')
C243 = np.loadtxt('/Scr/arango/ergosterol-amb/1-WorkflowDevelopment/3-analysis/0-DCC/test.CHL.243.dat')
CAMB = np.loadtxt('/Scr/arango/ergosterol-amb/1-WorkflowDevelopment/3-analysis/0-DCC/test.CHL.AMB.dat')
CEPI = np.loadtxt('/Scr/arango/ergosterol-amb/1-WorkflowDevelopment/3-analysis/0-DCC/test.CHL.EPI.dat')

E219 = np.loadtxt('/Scr/arango/ergosterol-amb/1-WorkflowDevelopment/3-analysis/0-DCC/test.ERG.219.dat')
E243 = np.loadtxt('/Scr/arango/ergosterol-amb/1-WorkflowDevelopment/3-analysis/0-DCC/test.ERG.243.dat')
EAMB = np.loadtxt('/Scr/arango/ergosterol-amb/1-WorkflowDevelopment/3-analysis/0-DCC/test.ERG.AMB.dat')
EEPI = np.loadtxt('/Scr/arango/ergosterol-amb/1-WorkflowDevelopment/3-analysis/0-DCC/test.ERG.EPI.dat')

# %%
fig, ((ax1, ax2, ax3, ax4, ax5), (ax6, ax7, ax8, ax9, ax10))= plt.subplots(nrows=2, ncols=5,figsize=(20,15))
#CHL 
sns.heatmap(C219, vmin=0.0, vmax=1.0, cmap='Spectral', ax=ax1, cbar=False)
ax1.set_xticks([])

sns.heatmap(C243, vmin=0.0, vmax=1.0, cmap='Spectral', ax=ax2, cbar=False)
ax2.set_ylabel("")  # remove y label, but keep ticks
ax2.set_yticks([])
ax2.set_xticks([])

sns.heatmap(CAMB, vmin=0.0, vmax=1.0, cmap='Spectral', ax=ax3, cbar=False)

ax3.set_ylabel("")  # remove y label, but keep ticks
ax3.set_yticks([])
ax3.set_xticks([])

sns.heatmap(CEPI, vmin=0.0, vmax=1.0, cmap='Spectral', ax=ax4, cbar=False)
ax4.set_ylabel("")  # remove y label, but keep ticks
ax4.set_yticks([])
ax4.set_xticks([])

#COLORBAR
sns.heatmap(rs, vmin=0.0, vmax=1.0, cmap='Spectral', ax=ax5)
ax5.set_yticks([])
ax5.set_xticks([])


sns.heatmap(E219, vmin=0.0, vmax=1.0, cmap='Spectral', ax=ax6, cbar=False)

sns.heatmap(E243, vmin=0.0, vmax=1.0, cmap='Spectral', ax=ax7, cbar=False)

ax7.set_ylabel("")  # remove y label, but keep ticks
ax7.set_yticks([])

sns.heatmap(EAMB, vmin=0.0, vmax=1.0, cmap='Spectral', ax=ax8, cbar=False)

ax8.set_ylabel("")  # remove y label, but keep ticks
ax8.set_yticks([])

sns.heatmap(EEPI, vmin=0.0, vmax=1.0, cmap='Spectral', ax=ax9, cbar=False)

ax9.set_ylabel("")  # remove y label, but keep ticks
ax9.set_yticks([])

sns.heatmap(rs, vmin=0.0, vmax=1.0, cmap='Spectral', ax=ax10)

ax10.set_ylabel("")  # remove y label, but keep ticks
ax10.set_yticks([])

plt.show()

# %%
rs = [C219, C243, CAMB, CEPI, E219, E243, EAMB, EEPI]
print(E243)
# Out:
# [[ 1.        0.312162 -0.819693 ...  0.517478 -0.289034 -0.564458]
#  [ 0.312162  1.        0.088072 ...  0.537301  0.473434  0.313072]
#  [-0.819693  0.088072  1.       ... -0.617253  0.784889  0.935278]
#  ...
#  [ 0.517478  0.537301 -0.617253 ...  1.       -0.484462 -0.57742 ]
#  [-0.289034  0.473434  0.784889 ... -0.484462  1.        0.953159]
#  [-0.564458  0.313072  0.935278 ... -0.57742   0.953159  1.      ]]

# %%
fig, axn = plt.subplots(2, 4, sharex=True, sharey=True,figsize=(20,10))
cbar_ax = fig.add_axes([.91, .3, .03, .4])

for i, ax in enumerate(axn.flat):
    sns.heatmap(rs[i], ax=ax,
                cbar=i == 0,
                vmin=-1, vmax=1,
                cmap='Spectral',
                cbar_ax=None if i else cbar_ax)

#ax.xaxis.set_major_locator(ticker.MultipleLocator(5))
fig.savefig('DCC_Analysis_1ns.png', dpi=600)    
#fig.tight_layout(rect=[0, 0, .9, 1])

# %% [markdown]
# # Dihedral Analysis 1ns

# %%
import MDAnalysis as mda
from MDAnalysis.analysis.dihedrals import Dihedral
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import cm

name = "CHL.EPI"
def dihe(ag):
    a = ag.dihedral
    b = ag.value()
    return b
result = []
reslist = [10, 11, 12, 123, 124, 125, 26, 27, 28, 32, 33, 34, 37, 38, 39, 4, 5, 54, 55, 56, 59, 6, 60, 61, 65, 66, 67]

#################################################################

for e in range(1):
    #result.append("/Scr/arango/ergosterol-amb/dgx_runs/compound_screen/"+str(name)+".fep/run/f"+str(e)+"/f"+str(e)+".dcd")
    u = mda.Universe("/Scr/arango/ergosterol-amb/1-WorkflowDevelopment/5-forpaper/"+str(name)+".0/min/1.psf", 
                 "/Scr/arango/ergosterol-amb/1-WorkflowDevelopment/5-forpaper/"+str(name)+".0/min/1.eqnB.dcd")
    psi_list1 = []
    psi_list2 = []
    psi_list3 = []
    for res in reslist:
        psi_anglex = u.atoms.select_atoms('resname AMB and resid '+str(res)+' and name C7 O5 C12 C15')
        psi_anglex = psi_anglex.dihedral # convert AtomGroup to Dihedral object
        psi_angley = u.select_atoms('resname AMB and resid '+str(res)+' and  name C7 O5 C12 C10')
        psi_angley = psi_angley.dihedral # convert AtomGroup to Dihedral object
        #psi_anglez = u.select_atoms('resname AMB and resid '+str(res)+' and  name C8 C6 C4 C2')
        #psi_anglez = psi_anglez.dihedral # convert AtomGroup to Dihedral object
        for ts in u.trajectory:
            psi_list1.append(dihe(psi_anglex))
            psi_list2.append(dihe(psi_angley))
            #psi_list3.append(dihe(psi_anglez))
        #print(psi_list)
    df1 = pd.DataFrame(psi_list1)
    df2 = pd.DataFrame(psi_list2)
    #df3 = pd.DataFrame(psi_list3)
    df1.to_csv('./data_dihedrals/out1.'+str(name)+'.'+str(e)+'.csv')
    df2.to_csv('./data_dihedrals/out2.'+str(name)+'.'+str(e)+'.csv')
    #with open(f"file3{name}.txt", "w") as output:
    #    output.write(psi_list3)
#PHI-2
reslist1 = [100, 109, 112, 115, 124, 127, 130, 169, 172, 175, 184, 187, 190, 199, 202, 205, 244, 247, 250, 259, 262, 265, 274, 277, 280, 94, 97]
reslist2 = [101, 110, 113, 116, 125, 128, 131, 170, 173, 176, 185, 188, 191, 200, 203, 206, 245, 248, 251, 260, 263, 266, 275, 278, 281, 95, 98]
#################################################################

for e in range(1):
    #result.append("/Scr/arango/ergosterol-amb/dgx_runs/compound_screen/"+str(name)+".fep/run/f"+str(e)+"/f"+str(e)+".dcd")
    u = mda.Universe("/Scr/arango/ergosterol-amb/1-WorkflowDevelopment/5-forpaper/"+str(name)+".0/min/1.psf", 
                 "/Scr/arango/ergosterol-amb/1-WorkflowDevelopment/5-forpaper/"+str(name)+".0/min/1.eqnB.dcd")
    psi_list1 = []
    psi_list2 = []
    psi_list3 = []
    for res in range(len(reslist1)):
        psi_anglex = u.atoms.select_atoms('resname CHL1 and resid '+str(reslist1[res-1])+' and name C17 C20 C22 C23')
        psi_anglex = psi_anglex.dihedral # convert AtomGroup to Dihedral object
        psi_angley = u.select_atoms('resname CHL1 and resid '+str(reslist2[res-1])+' and  name C17 C20 C22 C23')
        psi_angley = psi_angley.dihedral # convert AtomGroup to Dihedral object
        #psi_anglez = u.select_atoms('resname AMB and resid '+str(res)+' and  name C8 C6 C4 C2')
        #psi_anglez = psi_anglez.dihedral # convert AtomGroup to Dihedral object
        for ts in u.trajectory:
            psi_list1.append(dihe(psi_anglex))
            psi_list2.append(dihe(psi_angley))
            #psi_list3.append(dihe(psi_anglez))
        #print(psi_list)
    df1 = pd.DataFrame(psi_list1)
    df2 = pd.DataFrame(psi_list2)
    #df3 = pd.DataFrame(psi_list3)
    df1.to_csv('./data_dihedrals/Phii1.'+str(name)+'.'+str(e)+'.csv')
    df2.to_csv('./data_dihedrals/Phii2.'+str(name)+'.'+str(e)+'.csv')
    #with open(f"file3{name}.txt", "w") as output:
    #    output.write(psi_list3)

# %%
import MDAnalysis as mda
from MDAnalysis.analysis.dihedrals import Dihedral
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import cm

name = "ERG.EPI"
def dihe(ag):
    a = ag.dihedral
    b = ag.value()
    return b
result = []
reslist = [10, 11, 12, 123, 124, 125, 26, 27, 28, 32, 33, 34, 37, 38, 39, 4, 5, 54, 55, 56, 59, 6, 60, 61, 65, 66, 67]

#################################################################

for e in range(1):
    #result.append("/Scr/arango/ergosterol-amb/dgx_runs/compound_screen/"+str(name)+".fep/run/f"+str(e)+"/f"+str(e)+".dcd")
    u = mda.Universe("/Scr/arango/ergosterol-amb/1-WorkflowDevelopment/5-forpaper/"+str(name)+".0/min/1.psf", 
                 "/Scr/arango/ergosterol-amb/1-WorkflowDevelopment/5-forpaper/"+str(name)+".0/min/1.eqnB.dcd")
    psi_list1 = []
    psi_list2 = []
    psi_list3 = []
    for res in reslist:
        psi_anglex = u.atoms.select_atoms('resname AMB and resid '+str(res)+' and name C7 O5 C12 C15')
        psi_anglex = psi_anglex.dihedral # convert AtomGroup to Dihedral object
        psi_angley = u.select_atoms('resname AMB and resid '+str(res)+' and  name C7 O5 C12 C10')
        psi_angley = psi_angley.dihedral # convert AtomGroup to Dihedral object
        #psi_anglez = u.select_atoms('resname AMB and resid '+str(res)+' and  name C8 C6 C4 C2')
        #psi_anglez = psi_anglez.dihedral # convert AtomGroup to Dihedral object
        for ts in u.trajectory:
            psi_list1.append(dihe(psi_anglex))
            psi_list2.append(dihe(psi_angley))
            #psi_list3.append(dihe(psi_anglez))
        #print(psi_list)
    df1 = pd.DataFrame(psi_list1)
    df2 = pd.DataFrame(psi_list2)
    #df3 = pd.DataFrame(psi_list3)
    df1.to_csv('./data_dihedrals/out1.'+str(name)+'.'+str(e)+'.csv')
    df2.to_csv('./data_dihedrals/out2.'+str(name)+'.'+str(e)+'.csv')
    #with open(f"file3{name}.txt", "w") as output:
    #    output.write(psi_list3)
#PHI-2
reslist1 = [100, 109, 112, 115, 124, 127, 130, 169, 172, 175, 184, 187, 190, 199, 202, 205, 244, 247, 250, 259, 262, 265, 274, 277, 280, 94, 97]
reslist2 = [101, 110, 113, 116, 125, 128, 131, 170, 173, 176, 185, 188, 191, 200, 203, 206, 245, 248, 251, 260, 263, 266, 275, 278, 281, 95, 98]
#################################################################

for e in range(1):
    #result.append("/Scr/arango/ergosterol-amb/dgx_runs/compound_screen/"+str(name)+".fep/run/f"+str(e)+"/f"+str(e)+".dcd")
    u = mda.Universe("/Scr/arango/ergosterol-amb/1-WorkflowDevelopment/5-forpaper/"+str(name)+".0/min/1.psf", 
                 "/Scr/arango/ergosterol-amb/1-WorkflowDevelopment/5-forpaper/"+str(name)+".0/min/1.eqnB.dcd")
    psi_list1 = []
    psi_list2 = []
    psi_list3 = []
    for res in range(len(reslist1)):
        psi_anglex = u.atoms.select_atoms('resname ERG and resid '+str(reslist1[res])+' and name C17 C20 C22 C23')
        psi_anglex = psi_anglex.dihedral # convert AtomGroup to Dihedral object
        psi_angley = u.select_atoms('resname ERG and resid '+str(reslist2[res])+' and  name C17 C20 C22 C23')
        psi_angley = psi_angley.dihedral # convert AtomGroup to Dihedral object
        #psi_anglez = u.select_atoms('resname AMB and resid '+str(res)+' and  name C8 C6 C4 C2')
        #psi_anglez = psi_anglez.dihedral # convert AtomGroup to Dihedral object
        for ts in u.trajectory:
            psi_list1.append(dihe(psi_anglex))
            psi_list2.append(dihe(psi_angley))
            #psi_list3.append(dihe(psi_anglez))
        #print(psi_list)
    df1 = pd.DataFrame(psi_list1)
    df2 = pd.DataFrame(psi_list2)
    #df3 = pd.DataFrame(psi_list3)
    df1.to_csv('./data_dihedrals/Phii1.'+str(name)+'.'+str(e)+'.csv')
    df2.to_csv('./data_dihedrals/Phii2.'+str(name)+'.'+str(e)+'.csv')
    #with open(f"file3{name}.txt", "w") as output:
    #    output.write(psi_list3)

# %% [markdown]
# # For DGX runs analysis (while parallization is fixed)

# %%
##### TEMPLATE FOR DGX RUNS


import MDAnalysis as mda
from MDAnalysis.analysis.dihedrals import Dihedral
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import cm

name = "CHL.219"
def dihe(ag):
    a = ag.dihedral
    b = ag.value()
    return b
result = []
reslist = [13, 2, 28, 29, 45, 46, 47, 52, 53, 54, 57, 58, 59, 60, 71, 77, 78, 83, 84, 89, 90, 24, 82, 30, 76, 81, 88]

#################################################################

for e in range(16):
    #result.append("/Scr/arango/ergosterol-amb/dgx_runs/compound_screen/"+str(name)+".fep/run/f"+str(e)+"/f"+str(e)+".dcd")
    u = mda.Universe("/Scr/arango/ergosterol-amb/1-WorkflowDevelopment/5-forpaper/"+str(name)+".0/min/1.psf", 
                 "/Scr/arango/ergosterol-amb/1-WorkflowDevelopment/5-forpaper/"+str(name)+".0/run/f"+str(e)+"/f"+str(e)+".dcd")
    psi_list1 = []
    psi_list2 = []
    psi_list3 = []
    for res in reslist:
        psi_anglex = u.atoms.select_atoms('resname AMB and resid '+str(res)+' and name C7 O5 C12 C15')
        psi_anglex = psi_anglex.dihedral # convert AtomGroup to Dihedral object
        psi_angley = u.select_atoms('resname AMB and resid '+str(res)+' and  name C7 O5 C12 C10')
        psi_angley = psi_angley.dihedral # convert AtomGroup to Dihedral object
        #psi_anglez = u.select_atoms('resname AMB and resid '+str(res)+' and  name C8 C6 C4 C2')
        #psi_anglez = psi_anglez.dihedral # convert AtomGroup to Dihedral object
        for ts in u.trajectory:
            psi_list1.append(dihe(psi_anglex))
            psi_list2.append(dihe(psi_angley))
            #psi_list3.append(dihe(psi_anglez))
        #print(psi_list)
    df1 = pd.DataFrame(psi_list1)
    df2 = pd.DataFrame(psi_list2)
    #df3 = pd.DataFrame(psi_list3)
    df1.to_csv('out1.'+str(name)+'.'+str(e)+'.csv')
    df2.to_csv('out2.'+str(name)+'.'+str(e)+'.csv')
    #with open(f"file3{name}.txt", "w") as output:
    #    output.write(psi_list3)
#PHI-2
    
reslist1 = [100, 109, 112, 115, 124, 127, 130, 169, 172, 175, 184, 187, 190, 199, 202, 205, 244, 247, 250, 259, 262, 265, 274, 277, 280, 94, 97]
reslist2 = [101, 110, 113, 116, 125, 128, 131, 170, 173, 176, 185, 188, 191, 200, 203, 206, 245, 248, 251, 260, 263, 266, 275, 278, 281, 95, 98]
#################################################################

for e in range(16):
    #result.append("/Scr/arango/ergosterol-amb/dgx_runs/compound_screen/"+str(name)+".fep/run/f"+str(e)+"/f"+str(e)+".dcd")
    u = mda.Universe("/Scr/arango/ergosterol-amb/1-WorkflowDevelopment/5-forpaper/"+str(name)+".0/min/1.psf", 
                 "/Scr/arango/ergosterol-amb/1-WorkflowDevelopment/5-forpaper/"+str(name)+".0/run/f"+str(e)+"/f"+str(e)+".dcd")
    psi_list1 = []
    psi_list2 = []
    psi_list3 = []
    for res in range(len(reslist1)):
        psi_anglex = u.atoms.select_atoms('resname CHL1 and resid '+str(reslist1[res])+' and name C17 C20 C22 C23')
        psi_anglex = psi_anglex.dihedral # convert AtomGroup to Dihedral object
        psi_angley = u.select_atoms('resname CHL1 and resid '+str(reslist2[res])+' and  name C17 C20 C22 C23')
        psi_angley = psi_angley.dihedral # convert AtomGroup to Dihedral object
        #psi_anglez = u.select_atoms('resname AMB and resid '+str(res)+' and  name C8 C6 C4 C2')
        #psi_anglez = psi_anglez.dihedral # convert AtomGroup to Dihedral object
        for ts in u.trajectory:
            psi_list1.append(dihe(psi_anglex))
            psi_list2.append(dihe(psi_angley))
            #psi_list3.append(dihe(psi_anglez))
        #print(psi_list)
    df1 = pd.DataFrame(psi_list1)
    df2 = pd.DataFrame(psi_list2)
    #df3 = pd.DataFrame(psi_list3)
    df1.to_csv('Phii1.'+str(name)+'.'+str(e)+'.csv')
    df2.to_csv('Phii2.'+str(name)+'.'+str(e)+'.csv')
    #with open(f"file3{name}.txt", "w") as output:
    #    output.write(psi_list3)

# %%
##### TEMPLATE FOR DGX RUNS


import MDAnalysis as mda
from MDAnalysis.analysis.dihedrals import Dihedral
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import cm

name = "CHL.EPI"
def dihe(ag):
    a = ag.dihedral
    b = ag.value()
    return b
result = []
reslist = [13, 2, 28, 29, 45, 46, 47, 52, 53, 54, 57, 58, 59, 60, 71, 77, 78, 83, 84, 89, 90, 24, 82, 30, 76, 81, 88]

#################################################################

for e in range(16):
    #result.append("/Scr/arango/ergosterol-amb/dgx_runs/compound_screen/"+str(name)+".fep/run/f"+str(e)+"/f"+str(e)+".dcd")
    u = mda.Universe("/Scr/arango/ergosterol-amb/1-WorkflowDevelopment/5-forpaper/"+str(name)+".0/min/1.psf", 
                 "/Scr/arango/ergosterol-amb/1-WorkflowDevelopment/5-forpaper/"+str(name)+".0/run/f"+str(e)+"/f"+str(e)+".dcd")
    psi_list1 = []
    psi_list2 = []
    psi_list3 = []
    for res in reslist:
        psi_anglex = u.atoms.select_atoms('resname AMB and resid '+str(res)+' and name C7 O5 C12 C15')
        psi_anglex = psi_anglex.dihedral # convert AtomGroup to Dihedral object
        psi_angley = u.select_atoms('resname AMB and resid '+str(res)+' and  name C7 O5 C12 C10')
        psi_angley = psi_angley.dihedral # convert AtomGroup to Dihedral object
        #psi_anglez = u.select_atoms('resname AMB and resid '+str(res)+' and  name C8 C6 C4 C2')
        #psi_anglez = psi_anglez.dihedral # convert AtomGroup to Dihedral object
        for ts in u.trajectory:
            psi_list1.append(dihe(psi_anglex))
            psi_list2.append(dihe(psi_angley))
            #psi_list3.append(dihe(psi_anglez))
        #print(psi_list)
    df1 = pd.DataFrame(psi_list1)
    df2 = pd.DataFrame(psi_list2)
    #df3 = pd.DataFrame(psi_list3)
    df1.to_csv('out1.'+str(name)+'.'+str(e)+'.csv')
    df2.to_csv('out2.'+str(name)+'.'+str(e)+'.csv')
    #with open(f"file3{name}.txt", "w") as output:
    #    output.write(psi_list3)
#PHI-2
    
reslist1 = [100, 109, 112, 115, 124, 127, 130, 169, 172, 175, 184, 187, 190, 199, 202, 205, 244, 247, 250, 259, 262, 265, 274, 277, 280, 94, 97]
reslist2 = [101, 110, 113, 116, 125, 128, 131, 170, 173, 176, 185, 188, 191, 200, 203, 206, 245, 248, 251, 260, 263, 266, 275, 278, 281, 95, 98]
#################################################################

for e in range(16):
    #result.append("/Scr/arango/ergosterol-amb/dgx_runs/compound_screen/"+str(name)+".fep/run/f"+str(e)+"/f"+str(e)+".dcd")
    u = mda.Universe("/Scr/arango/ergosterol-amb/1-WorkflowDevelopment/5-forpaper/"+str(name)+".0/min/1.psf", 
                 "/Scr/arango/ergosterol-amb/1-WorkflowDevelopment/5-forpaper/"+str(name)+".0/run/f"+str(e)+"/f"+str(e)+".dcd")
    psi_list1 = []
    psi_list2 = []
    psi_list3 = []
    for res in range(len(reslist1)):
        psi_anglex = u.atoms.select_atoms('resname CHL1 and resid '+str(reslist1[res])+' and name C17 C20 C22 C23')
        psi_anglex = psi_anglex.dihedral # convert AtomGroup to Dihedral object
        psi_angley = u.select_atoms('resname CHL1 and resid '+str(reslist2[res])+' and  name C17 C20 C22 C23')
        psi_angley = psi_angley.dihedral # convert AtomGroup to Dihedral object
        #psi_anglez = u.select_atoms('resname AMB and resid '+str(res)+' and  name C8 C6 C4 C2')
        #psi_anglez = psi_anglez.dihedral # convert AtomGroup to Dihedral object
        for ts in u.trajectory:
            psi_list1.append(dihe(psi_anglex))
            psi_list2.append(dihe(psi_angley))
            #psi_list3.append(dihe(psi_anglez))
        #print(psi_list)
    df1 = pd.DataFrame(psi_list1)
    df2 = pd.DataFrame(psi_list2)
    #df3 = pd.DataFrame(psi_list3)
    df1.to_csv('Phii1.'+str(name)+'.'+str(e)+'.csv')
    df2.to_csv('Phii2.'+str(name)+'.'+str(e)+'.csv')
    #with open(f"file3{name}.txt", "w") as output:
    #    output.write(psi_list3)

# %%
#reslist1 = "10 101 110 113 116 125 128 131 154 157 160 169 170 172 173 175 176 185 188 19 191 200 203 206 22 245 248 25 251 260 263 266 275 278 281 34 37 40 7 79 82 85 95 98"
#reslist2 = "4 127 130 199 202 205 274 277 280 259 262 265 184 187 259 262 265 184 187 190 109 112 115 94 97 100 109 244 172 247 250 175"
reslist1 = "100 101 109 110 112 113 115 116 124 125 127 128 130 131 169 170 172 173 175 176 184 185 187 188 190 191 199 200 202 203 205 206 244 245 247 248 250 251 259 260 262 263 265 266 274 275 277 278 280 281 94 95 97 98"
reslist2 = "100 109 112 115 124 127 130 169 172 175 184 187 190 199 202 205 244 247 250 259 262 265 274 277 280 94 97"
amb="13 2 28 29 45 46 47 52 53 54 57 58 59 60 71 77 78 83 84 89 90 24 82 30 76 81 88"
r1 = reslist1.split()
r2 = reslist2.split()
amb = amb.split()
amb = [int(item) for item in amb]
r2og = [int(item) for item in r2]
r2 = [int(item) for item in r2]
#r1 = sorted(r1)
#r2 = sorted(r2)

def remove_common(a, b):
 
    for i in a[:]:
        if i in b:
            a.remove(i)
            b.remove(i)
    
    return a
    #print("list1 : ", a)
    #print("list2 : ", b)


r3=remove_common(r1, r2)
#print(remove_common(r1, r2))
print(r2og)
print(r3)
print(amb)
print(len(amb))
# Out:
# [100, 109, 112, 115, 124, 127, 130, 169, 172, 175, 184, 187, 190, 199, 202, 205, 244, 247, 250, 259, 262, 265, 274, 277, 280, 94, 97]
# ['100', '101', '109', '110', '112', '113', '115', '116', '124', '125', '127', '128', '130', '131', '169', '170', '172', '173', '175', '176', '184', '185', '187', '188', '190', '191', '199', '200', '202', '203', '205', '206', '244', '245', '247', '248', '250', '251', '259', '260', '262', '263', '265', '266', '274', '275', '277', '278', '280', '281', '94', '95', '97', '98']
# [13, 2, 28, 29, 45, 46, 47, 52, 53, 54, 57, 58, 59, 60, 71, 77, 78, 83, 84, 89, 90, 24, 82, 30, 76, 81, 88]
# 27

# %%
for res in range(len(amb)):
    print(amb[res])
# Out:
# 13
# 2
# 28
# 29
# 45
# 46
# 47
# 52
# 53
# 54
# 57
# 58
# 59
# 60
# 71
# 77
# 78
# 83
# 84
# 89
# 90
# 24
# 82
# 30
# 76
# 81
# 88
