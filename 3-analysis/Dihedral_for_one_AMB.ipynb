# %%
import MDAnalysis as mda
from MDAnalysis.analysis.dihedrals import Dihedral
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import cm

# %%
name = "AMB.CHL"

result = []
for e in range(16):
    result.append("/Scr/arango/ergosterol-amb/dgx_runs/compound_screen/"+str(name)+".fep/run/f"+str(e)+"/f"+str(e)+".dcd")
    

u = mda.Universe("/Scr/arango/ergosterol-amb/sponge_simulations/copy/"+str(name)+"/1.psf", 
                 result)

# selection of atomgroups
#resids for central AMBs
# 
reslist = [10, 11, 12, 123, 124, 125, 26, 27, 28, 32, 33, 34, 37, 38, 39, 4, 5, 54, 55, 56, 59, 6, 60, 61, 65, 66, 67]
#print(len())

# %% [markdown]
# # Attempting to make code parallel

# %%
def dihe(ag):
    a = ag.dihedral
    b = ag.value()
    return b

# %%
psi_list1 = []
psi_list2 = []
psi_list3 = []
for res in reslist:
    psi_anglex = u.atoms.select_atoms('resname AMB and resid '+str(res)+' and name C7 O5 C12 C15')
    psi_anglex = psi_anglex.dihedral # convert AtomGroup to Dihedral object
    psi_angley = u.select_atoms('resname AMB and resid '+str(res)+' and  name C7 O5 C12 C10')
    psi_angley = psi_angley.dihedral # convert AtomGroup to Dihedral object
    #psi_anglez = u.select_atoms('resname AMB and resid '+str(res)+' and  name C8 C6 C4 C2')
    #psi_anglez = psi_anglez.dihedral # convert AtomGroup to Dihedral object
    for ts in u.trajectory:
        psi_list1.append(dihe(psi_anglex))
        psi_list2.append(dihe(psi_angley))
        #psi_list3.append(dihe(psi_anglez))
    #print(psi_list)

# %%
df1 = pd.DataFrame(psi_list1)
df2 = pd.DataFrame(psi_list2)
#df3 = pd.DataFrame(psi_list3)
with open(f"file1{name}.txt", "w") as output:
    output.write(psi_list1)
with open(f"file2{name}.txt", "w") as output:
    output.write(psi_list2)
#with open(f"file3{name}.txt", "w") as output:
#    output.write(psi_list3)

# %% [markdown]
# ## OLD FILES BELOW

# %%
import MDAnalysis as mda
from MDAnalysis.analysis.dihedrals import Dihedral
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import cm

name = "AMB.CHL"
def dihe(ag):
    a = ag.dihedral
    b = ag.value()
    return b
result = []
reslist = [10, 11, 12, 123, 124, 125, 26, 27, 28, 32, 33, 34, 37, 38, 39, 4, 5, 54, 55, 56, 59, 6, 60, 61, 65, 66, 67]

#################################################################

for e in range(7, 16):
    #result.append("/Scr/arango/ergosterol-amb/dgx_runs/compound_screen/"+str(name)+".fep/run/f"+str(e)+"/f"+str(e)+".dcd")
    u = mda.Universe("/Scr/arango/ergosterol-amb/sponge_simulations/copy/"+str(name)+"/1.psf", 
                 "/Scr/arango/ergosterol-amb/dgx_runs/compound_screen/"+str(name)+".fep/run/f"+str(e)+"/f"+str(e)+".dcd")
    psi_list1 = []
    psi_list2 = []
    psi_list3 = []
    for res in reslist:
        psi_anglex = u.atoms.select_atoms('resname AMB and resid '+str(res)+' and name C7 O5 C12 C15')
        psi_anglex = psi_anglex.dihedral # convert AtomGroup to Dihedral object
        psi_angley = u.select_atoms('resname AMB and resid '+str(res)+' and  name C7 O5 C12 C10')
        psi_angley = psi_angley.dihedral # convert AtomGroup to Dihedral object
        #psi_anglez = u.select_atoms('resname AMB and resid '+str(res)+' and  name C8 C6 C4 C2')
        #psi_anglez = psi_anglez.dihedral # convert AtomGroup to Dihedral object
        for ts in u.trajectory:
            psi_list1.append(dihe(psi_anglex))
            psi_list2.append(dihe(psi_angley))
            #psi_list3.append(dihe(psi_anglez))
        #print(psi_list)
    df1 = pd.DataFrame(psi_list1)
    df2 = pd.DataFrame(psi_list2)
    #df3 = pd.DataFrame(psi_list3)
    df1.to_csv('out1.'+str(name)+'.'+str(e)+'.csv')
    df2.to_csv('out2.'+str(name)+'.'+str(e)+'.csv')
    #with open(f"file3{name}.txt", "w") as output:
    #    output.write(psi_list3)

# %%
import MDAnalysis as mda
from MDAnalysis.analysis.dihedrals import Dihedral
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import cm

name = "AMB.ERG"
def dihe(ag):
    a = ag.dihedral
    b = ag.value()
    return b
result = []
reslist = [10, 11, 12, 123, 124, 125, 26, 27, 28, 32, 33, 34, 37, 38, 39, 4, 5, 54, 55, 56, 59, 6, 60, 61, 65, 66, 67]

#################################################################

for e in range(16):
    #result.append("/Scr/arango/ergosterol-amb/dgx_runs/compound_screen/"+str(name)+".fep/run/f"+str(e)+"/f"+str(e)+".dcd")
    u = mda.Universe("/Scr/arango/ergosterol-amb/sponge_simulations/copy/"+str(name)+"/1.psf", 
                 "/Scr/arango/ergosterol-amb/dgx_runs/compound_screen/"+str(name)+".fep/run/f"+str(e)+"/f"+str(e)+".dcd")
    psi_list1 = []
    psi_list2 = []
    psi_list3 = []
    for res in reslist:
        psi_anglex = u.atoms.select_atoms('resname AMB and resid '+str(res)+' and name C7 O5 C12 C15')
        psi_anglex = psi_anglex.dihedral # convert AtomGroup to Dihedral object
        psi_angley = u.select_atoms('resname AMB and resid '+str(res)+' and  name C7 O5 C12 C10')
        psi_angley = psi_angley.dihedral # convert AtomGroup to Dihedral object
        #psi_anglez = u.select_atoms('resname AMB and resid '+str(res)+' and  name C8 C6 C4 C2')
        #psi_anglez = psi_anglez.dihedral # convert AtomGroup to Dihedral object
        for ts in u.trajectory:
            psi_list1.append(dihe(psi_anglex))
            psi_list2.append(dihe(psi_angley))
            #psi_list3.append(dihe(psi_anglez))
        #print(psi_list)
    df1 = pd.DataFrame(psi_list1)
    df2 = pd.DataFrame(psi_list2)
    #df3 = pd.DataFrame(psi_list3)
    df1.to_csv('out1.'+str(name)+'.'+str(e)+'.csv')
    df2.to_csv('out2.'+str(name)+'.'+str(e)+'.csv')
    #with open(f"file3{name}.txt", "w") as output:
    #    output.write(psi_list3)

# %%
import MDAnalysis as mda
from MDAnalysis.analysis.dihedrals import Dihedral
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import cm

name = "EPI.CHL"
def dihe(ag):
    a = ag.dihedral
    b = ag.value()
    return b
result = []
reslist = [10, 11, 12, 123, 124, 125, 26, 27, 28, 32, 33, 34, 37, 38, 39, 4, 5, 54, 55, 56, 59, 6, 60, 61, 65, 66, 67]

#################################################################

for e in range(16):
    #result.append("/Scr/arango/ergosterol-amb/dgx_runs/compound_screen/"+str(name)+".fep/run/f"+str(e)+"/f"+str(e)+".dcd")
    u = mda.Universe("/Scr/arango/ergosterol-amb/sponge_simulations/copy/"+str(name)+"/1.psf", 
                 "/Scr/arango/ergosterol-amb/dgx_runs/compound_screen/"+str(name)+".fep/run/f"+str(e)+"/f"+str(e)+".dcd")
    psi_list1 = []
    psi_list2 = []
    psi_list3 = []
    for res in reslist:
        psi_anglex = u.atoms.select_atoms('resname AMB and resid '+str(res)+' and name C7 O5 C12 C15')
        psi_anglex = psi_anglex.dihedral # convert AtomGroup to Dihedral object
        psi_angley = u.select_atoms('resname AMB and resid '+str(res)+' and  name C7 O5 C12 C10')
        psi_angley = psi_angley.dihedral # convert AtomGroup to Dihedral object
        #psi_anglez = u.select_atoms('resname AMB and resid '+str(res)+' and  name C8 C6 C4 C2')
        #psi_anglez = psi_anglez.dihedral # convert AtomGroup to Dihedral object
        for ts in u.trajectory:
            psi_list1.append(dihe(psi_anglex))
            psi_list2.append(dihe(psi_angley))
            #psi_list3.append(dihe(psi_anglez))
        #print(psi_list)
    df1 = pd.DataFrame(psi_list1)
    df2 = pd.DataFrame(psi_list2)
    #df3 = pd.DataFrame(psi_list3)
    df1.to_csv('out1.'+str(name)+'.'+str(e)+'.csv')
    df2.to_csv('out2.'+str(name)+'.'+str(e)+'.csv')
    #with open(f"file3{name}.txt", "w") as output:
    #    output.write(psi_list3)

# %%
import argparse
import MDAnalysis as mda
from MDAnalysis.analysis.dihedrals import Dihedral 
import pandas as pd
import ray
import os
import time
import functools

parser = argparse.ArgumentParser()
parser.add_argument('--psf', type=str, default=None)
parser.add_argument('--trajs', nargs="*", type=str, default=None)
parser.add_argument('--resname', nargs="*", typer=str, default="AMB")
parser.add_argument('--multip', action="store_true", help="enable multiprocessing?")
parser.add_argument('--get_cartesian', type=bool, default=True, help="MDA data extraction")
parser.add_argument('--filename', type=str, default="default.npy") 
parser.add_argument('--data_dir', type=str, default=None)
parser.add_argument('--selections', type=str, default = 'resname AMB and name C7 O5 C12 C10')
args = parser.parse_args()

@ray.remote
def dihe_mp(ag, timestep):
    ag.universe.trajectory[timestep]
    a = ag.dihedral
    b = ag.value()
    return b

class DihedralMultipro(object):
    def __init__(self, args: arparse.ArgumentParser):
        #Extracting parsed information from the object
        [setattr(self, key, val) for key, val in args.__dict__.items()]
    
    @staticmethod
    def load_traj(data_dir: str, psf: str, trajs: List[str], selections: str):
        assert pdb is not None, "Need psf to continue"
        assert trajs is not None, "DCD(s) must be provided"
        top = psf
        top = os.path.join(data_dir, top)
        trajs = list(map(lambda inp: os.path.join(data_dir, inp), trajs ))
        prot_traj = mda.Universe(top, *trajs)
        print("MDA Universe is created")
        
        return prot_traj.select_atoms(selections)
    
    @property
    def calculate_dihe_trajs(self, ):
        s = time.time()
        print(self.__dict__)
        prot_ags = self.load_traj(self.data_dir, self.psf, self.trajs, self.selections)
        times = len(prot_ags.universe.trajectory)
        _diheds = [dihe_mp.remote(ag=prot_ags, timestep=frame) for frame in range(times)]
        diheds = ray.get(_diheds)
        return diheds
    
    def __call__(self, ):
        return self.calculate_dihe_trajs

dihedral = DihedralMultipro(args)
diheds = dihedral() #dihedral.calculate_dihe_trajs

# %%
import argparse
import MDAnalysis as mda
from MDAnalysis.analysis.dihedrals import Dihedral
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import cm
import time
s = time.time()
name = "EPI.ERG"
def dihe(ag):
#     ag.universe.trajectory[timestep]
    a = ag.dihedral
    b = ag.value()
    return b
result = []
reslist = [ 54]

#################################################################


#result.append("/Scr/arango/ergosterol-amb/dgx_runs/compound_screen/"+str(name)+".fep/run/f"+str(e)+"/f"+str(e)+".dcd")
u = mda.Universe("/Scr/arango/ergosterol-amb/1-WorkflowDevelopment/5-forpaper/CHL.AMB.0/min/1.psf", 
                 "/Scr/arango/ergosterol-amb/1-WorkflowDevelopment/5-forpaper/CHL.AMB.0/min/1.eqnA.dcd")
psi_list1 = []
for res in reslist:
    psi_anglex = u.atoms.select_atoms('resname AMB and resid 54 and name C7 O5 C12 C10')
    psi_anglex = psi_anglex.dihedral # convert AtomGroup to Dihedral object
        #psi_angley = u.select_atoms('resname AMB and resid '+str(res)+' and  name C7 O5 C12 C10')
        #psi_angley = psi_angley.dihedral # convert AtomGroup to Dihedral object
        #psi_anglez = u.select_atoms('resname AMB and resid '+str(res)+' and  name C8 C6 C4 C2')
        #psi_anglez = psi_anglez.dihedral # convert AtomGroup to Dihedral object
    for ts in u.trajectory:
        psi_list1.append(dihe(psi_anglex))
            #psi_list2.append(dihe(psi_angley))
            #psi_list3.append(dihe(psi_anglez))
            
print(psi_list1)
e = time.time()
print(f"Took {e-s} seconds...")
print("Done!")
# Out:
# [61.582613588776596, 41.397783784369146, 58.64428215008989, 25.581573189298947, 42.2381617209091, 50.803059217838836, 55.90536529812729, 54.762106060646595, 29.198996265467557, 43.92453330549846, 49.90922347086373, 52.373516673931235, 16.90333115591435, 42.26311534171587, 44.22510563450135, 46.20148692348636, 57.121444936674514, 44.095302509298534, 47.08820250826937, 40.20186836675071, 29.28750393378531, 59.433647627382896, 43.80991096268001, 50.29775307838438, 44.27688781242592, 55.39428326252117, 38.725594988471734, 58.97609354279753, 58.45514089800729, 54.42951719204644, 48.06793658570672, 46.48076949324844, 53.09061759585522, 40.29801868878457, 38.952291739102996, 43.10481586145107, 31.039775667191662, 51.42475338245986, 58.30711101889757, 50.218442851782065, 38.73003380484783, 50.791728181976374, 49.90631157773303, 43.09632432628327, 43.883816241113706, 46.06155075941167, 38.788864050823776, 36.154953214327534, 42.438520844045996, 41.84906886053951, 59.83465567567237, 40.2777705
# ...

# %%
import argparse
import MDAnalysis as mda
from MDAnalysis.analysis.dihedrals import Dihedral
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import cm

name = "EPI.ERG"
def dihe(ag):
#     ag.universe.trajectory[timestep]
    a = ag.dihedral
    b = ag.value()
    return b
result = []
reslist = [10, 11, 12, 123, 124, 125, 26, 27, 28, 32, 33, 34, 37, 38, 39, 4, 5, 54, 55, 56, 59, 6, 60, 61, 65, 66, 67]

#################################################################

for e in range(16):
    #result.append("/Scr/arango/ergosterol-amb/dgx_runs/compound_screen/"+str(name)+".fep/run/f"+str(e)+"/f"+str(e)+".dcd")
    u = mda.Universe("/Scr/arango/ergosterol-amb/sponge_simulations/copy/"+str(name)+"/1.psf", 
                 "/Scr/arango/ergosterol-amb/dgx_runs/compound_screen/"+str(name)+".fep/run/f"+str(e)+"/f"+str(e)+".dcd")
    psi_list1 = []
    psi_list2 = []
    psi_list3 = []
    for res in reslist:
        psi_anglex = u.atoms.select_atoms('resname AMB and resid '+str(res)+' and name C7 O5 C12 C15')
        psi_anglex = psi_anglex.dihedral # convert AtomGroup to Dihedral object
        psi_angley = u.select_atoms('resname AMB and resid '+str(res)+' and  name C7 O5 C12 C10')
        psi_angley = psi_angley.dihedral # convert AtomGroup to Dihedral object
        #psi_anglez = u.select_atoms('resname AMB and resid '+str(res)+' and  name C8 C6 C4 C2')
        #psi_anglez = psi_anglez.dihedral # convert AtomGroup to Dihedral object
        for ts in u.trajectory:
            psi_list1.append(dihe(psi_anglex))
            psi_list2.append(dihe(psi_angley))
            #psi_list3.append(dihe(psi_anglez))
        #print(psi_list)
    df1 = pd.DataFrame(psi_list1)
    df2 = pd.DataFrame(psi_list2)
    #df3 = pd.DataFrame(psi_list3)
    df1.to_csv('out1.'+str(name)+'.'+str(e)+'.csv')
    df2.to_csv('out2.'+str(name)+'.'+str(e)+'.csv')
    #with open(f"file3{name}.txt", "w") as output:
    #    output.write(psi_list3)

# %%
######################
######ERGOSTEROL PHI2#######
######################
import MDAnalysis as mda
from MDAnalysis.analysis.dihedrals import Dihedral
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import cm

name = "AMB.ERG"
def dihe(ag):
    a = ag.dihedral
    b = ag.value()
    return b
result = []
#reslist = [80, 51, 24, 120, 8, 121, 110, 74, 1, 116, 20, 47, 76, 77, 78, 79, 117, 21, 48, 49, 50, 118, 22, 119, 23]
reslist1 = [137, 82, 26, 220, 126, 70, 15, 209, 121, 4, 59, 115, 134, 80, 23, 218, 124, 67, 13, 206, 112, 57, 250, 99, 132, 78, 21, 216, 122, 65, 11, 187, 110, 55, 248, 77] 
reslist2 = [25, 81, 136, 191, 180, 125, 69, 14, 169, 114, 58, 3, 189, 133, 78, 22, 177, 123, 66, 12, 167, 111, 56, 249, 186, 131, 75, 20, 175, 120, 64, 9, 164, 109, 53, 247]
#################################################################

for e in range(16):
    #result.append("/Scr/arango/ergosterol-amb/dgx_runs/compound_screen/"+str(name)+".fep/run/f"+str(e)+"/f"+str(e)+".dcd")
    u = mda.Universe("/Scr/arango/ergosterol-amb/sponge_simulations/copy/"+str(name)+"/1.psf", 
                 "/Scr/arango/ergosterol-amb/dgx_runs/compound_screen/"+str(name)+".fep/run/f"+str(e)+"/f"+str(e)+".dcd")
    psi_list1 = []
    psi_list2 = []
    psi_list3 = []
    for res in range(36):
        psi_anglex = u.atoms.select_atoms('resname ERG and resid '+str(reslist1[res])+' and name C17 C20 C22 C23')
        psi_anglex = psi_anglex.dihedral # convert AtomGroup to Dihedral object
        psi_angley = u.select_atoms('resname ERG and resid '+str(reslist2[res])+' and  name C17 C20 C22 C23')
        psi_angley = psi_angley.dihedral # convert AtomGroup to Dihedral object
        #psi_anglez = u.select_atoms('resname AMB and resid '+str(res)+' and  name C8 C6 C4 C2')
        #psi_anglez = psi_anglez.dihedral # convert AtomGroup to Dihedral object
        for ts in u.trajectory:
            psi_list1.append(dihe(psi_anglex))
            psi_list2.append(dihe(psi_angley))
            #psi_list3.append(dihe(psi_anglez))
        #print(psi_list)
    df1 = pd.DataFrame(psi_list1)
    df2 = pd.DataFrame(psi_list2)
    #df3 = pd.DataFrame(psi_list3)
    df1.to_csv('Phii1.'+str(name)+'.'+str(e)+'.csv')
    df2.to_csv('Phii2.'+str(name)+'.'+str(e)+'.csv')
    #with open(f"file3{name}.txt", "w") as output:
    #    output.write(psi_list3)

# %%
######################
######ERGOSTEROL PHI2#######
######################
import MDAnalysis as mda
from MDAnalysis.analysis.dihedrals import Dihedral
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import cm

name = "EPI.ERG"
def dihe(ag):
    a = ag.dihedral
    b = ag.value()
    return b
result = []
#reslist = [80, 51, 24, 120, 8, 121, 110, 74, 1, 116, 20, 47, 76, 77, 78, 79, 117, 21, 48, 49, 50, 118, 22, 119, 23]
reslist1 = [137, 82, 26, 220, 126, 70, 15, 209, 121, 4, 59, 115, 134, 80, 23, 218, 124, 67, 13, 206, 112, 57, 250, 99, 132, 78, 21, 216, 122, 65, 11, 187, 110, 55, 248, 77] 
reslist2 = [25, 81, 136, 191, 180, 125, 69, 14, 169, 114, 58, 3, 189, 133, 78, 22, 177, 123, 66, 12, 167, 111, 56, 249, 186, 131, 75, 20, 175, 120, 64, 9, 164, 109, 53, 247]
#################################################################

for e in range(16):
    #result.append("/Scr/arango/ergosterol-amb/dgx_runs/compound_screen/"+str(name)+".fep/run/f"+str(e)+"/f"+str(e)+".dcd")
    u = mda.Universe("/Scr/arango/ergosterol-amb/sponge_simulations/copy/"+str(name)+"/1.psf", 
                 "/Scr/arango/ergosterol-amb/dgx_runs/compound_screen/"+str(name)+".fep/run/f"+str(e)+"/f"+str(e)+".dcd")
    psi_list1 = []
    psi_list2 = []
    psi_list3 = []
    for res in range(36):
        psi_anglex = u.atoms.select_atoms('resname ERG and resid '+str(reslist1[res])+' and name C17 C20 C22 C23')
        psi_anglex = psi_anglex.dihedral # convert AtomGroup to Dihedral object
        psi_angley = u.select_atoms('resname ERG and resid '+str(reslist2[res])+' and  name C17 C20 C22 C23')
        psi_angley = psi_angley.dihedral # convert AtomGroup to Dihedral object
        #psi_anglez = u.select_atoms('resname AMB and resid '+str(res)+' and  name C8 C6 C4 C2')
        #psi_anglez = psi_anglez.dihedral # convert AtomGroup to Dihedral object
        for ts in u.trajectory:
            psi_list1.append(dihe(psi_anglex))
            psi_list2.append(dihe(psi_angley))
            #psi_list3.append(dihe(psi_anglez))
        #print(psi_list)
    df1 = pd.DataFrame(psi_list1)
    df2 = pd.DataFrame(psi_list2)
    #df3 = pd.DataFrame(psi_list3)
    df1.to_csv('Phii1.'+str(name)+'.'+str(e)+'.csv')
    df2.to_csv('Phii2.'+str(name)+'.'+str(e)+'.csv')
    #with open(f"file3{name}.txt", "w") as output:
    #    output.write(psi_list3)

# %%
######################
######ERGOSTEROL PHI2#######
######################
import MDAnalysis as mda
from MDAnalysis.analysis.dihedrals import Dihedral
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import cm

name = "AMB.CHL"
def dihe(ag):
    a = ag.dihedral
    b = ag.value()
    return b
result = []
#reslist = [80, 51, 24, 120, 8, 121, 110, 74, 1, 116, 20, 47, 76, 77, 78, 79, 117, 21, 48, 49, 50, 118, 22, 119, 23]
reslist1 = [137, 82, 26, 220, 126, 70, 15, 209, 121, 4, 59, 115, 134, 80, 23, 218, 124, 67, 13, 206, 112, 57, 250, 99, 132, 78, 21, 216, 122, 65, 11, 187, 110, 55, 248, 77] 
reslist2 = [25, 81, 136, 191, 180, 125, 69, 14, 169, 114, 58, 3, 189, 133, 78, 22, 177, 123, 66, 12, 167, 111, 56, 249, 186, 131, 75, 20, 175, 120, 64, 9, 164, 109, 53, 247]
#################################################################

for e in range(16):
    #result.append("/Scr/arango/ergosterol-amb/dgx_runs/compound_screen/"+str(name)+".fep/run/f"+str(e)+"/f"+str(e)+".dcd")
    u = mda.Universe("/Scr/arango/ergosterol-amb/sponge_simulations/copy/"+str(name)+"/1.psf", 
                 "/Scr/arango/ergosterol-amb/dgx_runs/compound_screen/"+str(name)+".fep/run/f"+str(e)+"/f"+str(e)+".dcd")
    psi_list1 = []
    psi_list2 = []
    psi_list3 = []
    for res in range(36):
        psi_anglex = u.atoms.select_atoms('resname CHL1 and resid '+str(reslist1[res])+' and name C17 C20 C22 C23')
        psi_anglex = psi_anglex.dihedral # convert AtomGroup to Dihedral object
        psi_angley = u.select_atoms('resname CHL1 and resid '+str(reslist2[res])+' and  name C17 C20 C22 C23')
        psi_angley = psi_angley.dihedral # convert AtomGroup to Dihedral object
        #psi_anglez = u.select_atoms('resname AMB and resid '+str(res)+' and  name C8 C6 C4 C2')
        #psi_anglez = psi_anglez.dihedral # convert AtomGroup to Dihedral object
        for ts in u.trajectory:
            psi_list1.append(dihe(psi_anglex))
            psi_list2.append(dihe(psi_angley))
            #psi_list3.append(dihe(psi_anglez))
        #print(psi_list)
    df1 = pd.DataFrame(psi_list1)
    df2 = pd.DataFrame(psi_list2)
    #df3 = pd.DataFrame(psi_list3)
    df1.to_csv('Phii1.'+str(name)+'.'+str(e)+'.csv')
    df2.to_csv('Phii2.'+str(name)+'.'+str(e)+'.csv')
    #with open(f"file3{name}.txt", "w") as output:
    #    output.write(psi_list3)

# %%
######################
######ERGOSTEROL PHI2#######
######################
import MDAnalysis as mda
from MDAnalysis.analysis.dihedrals import Dihedral
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import cm

name = "EPI.CHL"
def dihe(ag):
    a = ag.dihedral
    b = ag.value()
    return b
result = []
#reslist = [80, 51, 24, 120, 8, 121, 110, 74, 1, 116, 20, 47, 76, 77, 78, 79, 117, 21, 48, 49, 50, 118, 22, 119, 23]
reslist1 = [137, 82, 26, 220, 126, 70, 15, 209, 121, 4, 59, 115, 134, 80, 23, 218, 124, 67, 13, 206, 112, 57, 250, 99, 132, 78, 21, 216, 122, 65, 11, 187, 110, 55, 248, 77] 
reslist2 = [25, 81, 136, 191, 180, 125, 69, 14, 169, 114, 58, 3, 189, 133, 78, 22, 177, 123, 66, 12, 167, 111, 56, 249, 186, 131, 75, 20, 175, 120, 64, 9, 164, 109, 53, 247]
#################################################################

for e in range(16):
    #result.append("/Scr/arango/ergosterol-amb/dgx_runs/compound_screen/"+str(name)+".fep/run/f"+str(e)+"/f"+str(e)+".dcd")
    u = mda.Universe("/Scr/arango/ergosterol-amb/sponge_simulations/copy/"+str(name)+"/1.psf", 
                 "/Scr/arango/ergosterol-amb/dgx_runs/compound_screen/"+str(name)+".fep/run/f"+str(e)+"/f"+str(e)+".dcd")
    psi_list1 = []
    psi_list2 = []
    psi_list3 = []
    for res in range(36):
        psi_anglex = u.atoms.select_atoms('resname CHL1 and resid '+str(reslist1[res])+' and name C17 C20 C22 C23')
        psi_anglex = psi_anglex.dihedral # convert AtomGroup to Dihedral object
        psi_angley = u.select_atoms('resname CHL1 and resid '+str(reslist2[res])+' and  name C17 C20 C22 C23')
        psi_angley = psi_angley.dihedral # convert AtomGroup to Dihedral object
        #psi_anglez = u.select_atoms('resname AMB and resid '+str(res)+' and  name C8 C6 C4 C2')
        #psi_anglez = psi_anglez.dihedral # convert AtomGroup to Dihedral object
        for ts in u.trajectory:
            psi_list1.append(dihe(psi_anglex))
            psi_list2.append(dihe(psi_angley))
            #psi_list3.append(dihe(psi_anglez))
        #print(psi_list)
    df1 = pd.DataFrame(psi_list1)
    df2 = pd.DataFrame(psi_list2)
    #df3 = pd.DataFrame(psi_list3)
    df1.to_csv('Phii1.'+str(name)+'.'+str(e)+'.csv')
    df2.to_csv('Phii2.'+str(name)+'.'+str(e)+'.csv')
    #with open(f"file3{name}.txt", "w") as output:
    #    output.write(psi_list3)

# %% [markdown]
# # ANALYSIS FOR AMB DERIVATES 243

# %%
import MDAnalysis as mda
from MDAnalysis.analysis.dihedrals import Dihedral
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import cm

name = "243.CHL"
def dihe(ag):
    a = ag.dihedral
    b = ag.value()
    return b
result = []
reslist = [10, 11, 12, 123, 124, 125, 26, 27, 28, 32, 33, 34, 37, 38, 39, 4, 5, 54, 55, 56, 59, 6, 60, 61, 65, 66, 67]

#################################################################

for e in range(16):
    #result.append("/Scr/arango/ergosterol-amb/dgx_runs/compound_screen/"+str(name)+".fep/run/f"+str(e)+"/f"+str(e)+".dcd")
    u = mda.Universe("/Scr/arango/ergosterol-amb/sponge_simulations/"+str(name)+"/1.psf", 
                 "/Scr/arango/ergosterol-amb/dgx_runs/compound_screen/"+str(name)+".fep/run/f"+str(e)+"/f"+str(e)+".dcd")
    psi_list1 = []
    psi_list2 = []
    psi_list3 = []
    for res in reslist:
        psi_anglex = u.atoms.select_atoms('resname AMB and resid '+str(res)+' and name C7 O5 C12 C15')
        psi_anglex = psi_anglex.dihedral # convert AtomGroup to Dihedral object
        psi_angley = u.select_atoms('resname AMB and resid '+str(res)+' and  name C7 O5 C12 C10')
        psi_angley = psi_angley.dihedral # convert AtomGroup to Dihedral object
        #psi_anglez = u.select_atoms('resname AMB and resid '+str(res)+' and  name C8 C6 C4 C2')
        #psi_anglez = psi_anglez.dihedral # convert AtomGroup to Dihedral object
        for ts in u.trajectory:
            psi_list1.append(dihe(psi_anglex))
            psi_list2.append(dihe(psi_angley))
            #psi_list3.append(dihe(psi_anglez))
        #print(psi_list)
    df1 = pd.DataFrame(psi_list1)
    df2 = pd.DataFrame(psi_list2)
    #df3 = pd.DataFrame(psi_list3)
    df1.to_csv('out1.'+str(name)+'.'+str(e)+'.csv')
    df2.to_csv('out2.'+str(name)+'.'+str(e)+'.csv')
    #with open(f"file3{name}.txt", "w") as output:
    #    output.write(psi_list3)

# %%
import MDAnalysis as mda
from MDAnalysis.analysis.dihedrals import Dihedral
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import cm

name = "243.ERG"
def dihe(ag):
    a = ag.dihedral
    b = ag.value()
    return b
result = []
reslist = [10, 11, 12, 123, 124, 125, 26, 27, 28, 32, 33, 34, 37, 38, 39, 4, 5, 54, 55, 56, 59, 6, 60, 61, 65, 66, 67]

#################################################################

for e in range(16):
    #result.append("/Scr/arango/ergosterol-amb/dgx_runs/compound_screen/"+str(name)+".fep/run/f"+str(e)+"/f"+str(e)+".dcd")
    u = mda.Universe("/Scr/arango/ergosterol-amb/sponge_simulations/"+str(name)+"/1.psf", 
                 "/Scr/arango/ergosterol-amb/dgx_runs/compound_screen/"+str(name)+".fep/run/f"+str(e)+"/f"+str(e)+".dcd")
    psi_list1 = []
    psi_list2 = []
    psi_list3 = []
    for res in reslist:
        psi_anglex = u.atoms.select_atoms('resname AMB and resid '+str(res)+' and name C7 O5 C12 C15')
        psi_anglex = psi_anglex.dihedral # convert AtomGroup to Dihedral object
        psi_angley = u.select_atoms('resname AMB and resid '+str(res)+' and  name C7 O5 C12 C10')
        psi_angley = psi_angley.dihedral # convert AtomGroup to Dihedral object
        #psi_anglez = u.select_atoms('resname AMB and resid '+str(res)+' and  name C8 C6 C4 C2')
        #psi_anglez = psi_anglez.dihedral # convert AtomGroup to Dihedral object
        for ts in u.trajectory:
            psi_list1.append(dihe(psi_anglex))
            psi_list2.append(dihe(psi_angley))
            #psi_list3.append(dihe(psi_anglez))
        #print(psi_list)
    df1 = pd.DataFrame(psi_list1)
    df2 = pd.DataFrame(psi_list2)
    #df3 = pd.DataFrame(psi_list3)
    df1.to_csv('out1.'+str(name)+'.'+str(e)+'.csv')
    df2.to_csv('out2.'+str(name)+'.'+str(e)+'.csv')
    #with open(f"file3{name}.txt", "w") as output:
    #    output.write(psi_list3)

# %%
######################
######CHOLESTEROL PHI2#######
######################
import MDAnalysis as mda
from MDAnalysis.analysis.dihedrals import Dihedral
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import cm

name = "243.CHL"
def dihe(ag):
    a = ag.dihedral
    b = ag.value()
    return b
result = []
#reslist = [80, 51, 24, 120, 8, 121, 110, 74, 1, 116, 20, 47, 76, 77, 78, 79, 117, 21, 48, 49, 50, 118, 22, 119, 23]
reslist1 = [137, 82, 26, 220, 126, 70, 15, 209, 121, 4, 59, 115, 134, 80, 23, 218, 124, 67, 13, 206, 112, 57, 250, 99, 132, 78, 21, 216, 122, 65, 11, 187, 110, 55, 248, 77] 
reslist2 = [25, 81, 136, 191, 180, 125, 69, 14, 169, 114, 58, 3, 189, 133, 78, 22, 177, 123, 66, 12, 167, 111, 56, 249, 186, 131, 75, 20, 175, 120, 64, 9, 164, 109, 53, 247]
#################################################################

for e in range(16):
    #result.append("/Scr/arango/ergosterol-amb/dgx_runs/compound_screen/"+str(name)+".fep/run/f"+str(e)+"/f"+str(e)+".dcd")
    u = mda.Universe("/Scr/arango/ergosterol-amb/sponge_simulations/"+str(name)+"/1.psf", 
                 "/Scr/arango/ergosterol-amb/dgx_runs/compound_screen/"+str(name)+".fep/run/f"+str(e)+"/f"+str(e)+".dcd")
    psi_list1 = []
    psi_list2 = []
    psi_list3 = []
    for res in range(36):
        psi_anglex = u.atoms.select_atoms('resname CHL1 and resid '+str(reslist1[res])+' and name C17 C20 C22 C23')
        psi_anglex = psi_anglex.dihedral # convert AtomGroup to Dihedral object
        psi_angley = u.select_atoms('resname CHL1 and resid '+str(reslist2[res])+' and  name C17 C20 C22 C23')
        psi_angley = psi_angley.dihedral # convert AtomGroup to Dihedral object
        #psi_anglez = u.select_atoms('resname AMB and resid '+str(res)+' and  name C8 C6 C4 C2')
        #psi_anglez = psi_anglez.dihedral # convert AtomGroup to Dihedral object
        for ts in u.trajectory:
            psi_list1.append(dihe(psi_anglex))
            psi_list2.append(dihe(psi_angley))
            #psi_list3.append(dihe(psi_anglez))
        #print(psi_list)
    df1 = pd.DataFrame(psi_list1)
    df2 = pd.DataFrame(psi_list2)
    #df3 = pd.DataFrame(psi_list3)
    df1.to_csv('Phii1.'+str(name)+'.'+str(e)+'.csv')
    df2.to_csv('Phii2.'+str(name)+'.'+str(e)+'.csv')
    #with open(f"file3{name}.txt", "w") as output:
    #    output.write(psi_list3)

# %%
######################
######ERGOSTEROL PHI2#######
######################
import MDAnalysis as mda
from MDAnalysis.analysis.dihedrals import Dihedral
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import cm

name = "243.ERG"
def dihe(ag):
    a = ag.dihedral
    b = ag.value()
    return b
result = []
#reslist = [80, 51, 24, 120, 8, 121, 110, 74, 1, 116, 20, 47, 76, 77, 78, 79, 117, 21, 48, 49, 50, 118, 22, 119, 23]
reslist1 = [137, 82, 26, 220, 126, 70, 15, 209, 121, 4, 59, 115, 134, 80, 23, 218, 124, 67, 13, 206, 112, 57, 250, 99, 132, 78, 21, 216, 122, 65, 11, 187, 110, 55, 248, 77] 
reslist2 = [25, 81, 136, 191, 180, 125, 69, 14, 169, 114, 58, 3, 189, 133, 78, 22, 177, 123, 66, 12, 167, 111, 56, 249, 186, 131, 75, 20, 175, 120, 64, 9, 164, 109, 53, 247]
#################################################################

for e in range(16):
    #result.append("/Scr/arango/ergosterol-amb/dgx_runs/compound_screen/"+str(name)+".fep/run/f"+str(e)+"/f"+str(e)+".dcd")
    u = mda.Universe("/Scr/arango/ergosterol-amb/sponge_simulations/"+str(name)+"/1.psf", 
                 "/Scr/arango/ergosterol-amb/dgx_runs/compound_screen/"+str(name)+".fep/run/f"+str(e)+"/f"+str(e)+".dcd")
    psi_list1 = []
    psi_list2 = []
    psi_list3 = []
    for res in range(36):
        psi_anglex = u.atoms.select_atoms('resname CHL1 and resid '+str(reslist1[res])+' and name C17 C20 C22 C23')
        psi_anglex = psi_anglex.dihedral # convert AtomGroup to Dihedral object
        psi_angley = u.select_atoms('resname CHL1 and resid '+str(reslist2[res])+' and  name C17 C20 C22 C23')
        psi_angley = psi_angley.dihedral # convert AtomGroup to Dihedral object
        #psi_anglez = u.select_atoms('resname AMB and resid '+str(res)+' and  name C8 C6 C4 C2')
        #psi_anglez = psi_anglez.dihedral # convert AtomGroup to Dihedral object
        for ts in u.trajectory:
            psi_list1.append(dihe(psi_anglex))
            psi_list2.append(dihe(psi_angley))
            #psi_list3.append(dihe(psi_anglez))
        #print(psi_list)
    df1 = pd.DataFrame(psi_list1)
    df2 = pd.DataFrame(psi_list2)
    #df3 = pd.DataFrame(psi_list3)
    df1.to_csv('Phii1.'+str(name)+'.'+str(e)+'.csv')
    df2.to_csv('Phii2.'+str(name)+'.'+str(e)+'.csv')
    #with open(f"file3{name}.txt", "w") as output:
    #    output.write(psi_list3)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-6-12bb8b9cd215> in <module>()
#      29     for res in range(36):
#      30         psi_anglex = u.atoms.select_atoms('resname CHL1 and resid '+str(reslist1[res])+' and name C17 C20 C22 C23')
# ---> 31         psi_anglex = psi_anglex.dihedral # convert AtomGroup to Dihedral object
#      32         psi_angley = u.select_atoms('resname CHL1 and resid '+str(reslist2[res])+' and  name C17 C20 C22 C23')
#      33         psi_angley = psi_angley.dihedral # convert AtomGroup to Dihedral object
#
# /Projects/arango/anaconda3/lib/python3.6/site-packages/MDAnalysis/core/groups.py in dihedral(self)
#    3012         if len(self) != 4:
#    3013             raise ValueError(
# -> 3014                 "dihedral only makes sense for a group with exactly 4 atoms")
# ...

# %% [markdown]
# # ANALYSIS FOR AMB DERIVATES 219 STEROLS PHI2

# %%
import MDAnalysis as mda
from MDAnalysis.analysis.dihedrals import Dihedral
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import cm

name = "219.CHL"
def dihe(ag):
    a = ag.dihedral
    b = ag.value()
    return b
result = []
reslist = [10, 11, 12, 123, 124, 125, 26, 27, 28, 32, 33, 34, 37, 38, 39, 4, 5, 54, 55, 56, 59, 6, 60, 61, 65, 66, 67]

#################################################################

for e in range(16):
    #result.append("/Scr/arango/ergosterol-amb/dgx_runs/compound_screen/"+str(name)+".fep/run/f"+str(e)+"/f"+str(e)+".dcd")
    u = mda.Universe("/Scr/arango/ergosterol-amb/sponge_simulations/"+str(name)+"/1.psf", 
                 "/Scr/arango/ergosterol-amb/dgx_runs/compound_screen/"+str(name)+".fep/run/f"+str(e)+"/f"+str(e)+".dcd")
    psi_list1 = []
    psi_list2 = []
    psi_list3 = []
    for res in reslist:
        psi_anglex = u.atoms.select_atoms('resname AMB and resid '+str(res)+' and name C7 O5 C12 C15')
        psi_anglex = psi_anglex.dihedral # convert AtomGroup to Dihedral object
        psi_angley = u.select_atoms('resname AMB and resid '+str(res)+' and  name C7 O5 C12 C10')
        psi_angley = psi_angley.dihedral # convert AtomGroup to Dihedral object
        #psi_anglez = u.select_atoms('resname AMB and resid '+str(res)+' and  name C8 C6 C4 C2')
        #psi_anglez = psi_anglez.dihedral # convert AtomGroup to Dihedral object
        for ts in u.trajectory:
            psi_list1.append(dihe(psi_anglex))
            psi_list2.append(dihe(psi_angley))
            #psi_list3.append(dihe(psi_anglez))
        #print(psi_list)
    df1 = pd.DataFrame(psi_list1)
    df2 = pd.DataFrame(psi_list2)
    #df3 = pd.DataFrame(psi_list3)
    df1.to_csv('out1.'+str(name)+'.'+str(e)+'.csv')
    df2.to_csv('out2.'+str(name)+'.'+str(e)+'.csv')
    #with open(f"file3{name}.txt", "w") as output:
    #    output.write(psi_list3)

# %%
######################
######CHOLESTEROL PHI2#######
######################
import MDAnalysis as mda
from MDAnalysis.analysis.dihedrals import Dihedral
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import cm

name = "219.CHL"
def dihe(ag):
    a = ag.dihedral
    b = ag.value()
    return b
result = []
#reslist = [80, 51, 24, 120, 8, 121, 110, 74, 1, 116, 20, 47, 76, 77, 78, 79, 117, 21, 48, 49, 50, 118, 22, 119, 23]
reslist1 = [137, 82, 26, 220, 126, 70, 15, 209, 121, 4, 59, 115, 134, 80, 23, 218, 124, 67, 13, 206, 112, 57, 250, 99, 132, 78, 21, 216, 122, 65, 11, 187, 110, 55, 248, 77] 
reslist2 = [25, 81, 136, 191, 180, 125, 69, 14, 169, 114, 58, 3, 189, 133, 78, 22, 177, 123, 66, 12, 167, 111, 56, 249, 186, 131, 75, 20, 175, 120, 64, 9, 164, 109, 53, 247]
#################################################################

for e in range(16):
    #result.append("/Scr/arango/ergosterol-amb/dgx_runs/compound_screen/"+str(name)+".fep/run/f"+str(e)+"/f"+str(e)+".dcd")
    u = mda.Universe("/Scr/arango/ergosterol-amb/sponge_simulations/"+str(name)+"/1.psf", 
                 "/Scr/arango/ergosterol-amb/dgx_runs/compound_screen/"+str(name)+".fep/run/f"+str(e)+"/f"+str(e)+".dcd")
    psi_list1 = []
    psi_list2 = []
    psi_list3 = []
    for res in range(36):
        psi_anglex = u.atoms.select_atoms('resname CHL1 and resid '+str(reslist1[res])+' and name C17 C20 C22 C23')
        psi_anglex = psi_anglex.dihedral # convert AtomGroup to Dihedral object
        psi_angley = u.select_atoms('resname CHL1 and resid '+str(reslist2[res])+' and  name C17 C20 C22 C23')
        psi_angley = psi_angley.dihedral # convert AtomGroup to Dihedral object
        #psi_anglez = u.select_atoms('resname AMB and resid '+str(res)+' and  name C8 C6 C4 C2')
        #psi_anglez = psi_anglez.dihedral # convert AtomGroup to Dihedral object
        for ts in u.trajectory:
            psi_list1.append(dihe(psi_anglex))
            psi_list2.append(dihe(psi_angley))
            #psi_list3.append(dihe(psi_anglez))
        #print(psi_list)
    df1 = pd.DataFrame(psi_list1)
    df2 = pd.DataFrame(psi_list2)
    #df3 = pd.DataFrame(psi_list3)
    df1.to_csv('Phii1.'+str(name)+'.'+str(e)+'.csv')
    df2.to_csv('Phii2.'+str(name)+'.'+str(e)+'.csv')
    #with open(f"file3{name}.txt", "w") as output:
    #    output.write(psi_list3)

# %%
import MDAnalysis as mda
from MDAnalysis.analysis.dihedrals import Dihedral
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import cm

name = "219.ERG"
def dihe(ag):
    a = ag.dihedral
    b = ag.value()
    return b
result = []
reslist = [10, 11, 12, 123, 124, 125, 26, 27, 28, 32, 33, 34, 37, 38, 39, 4, 5, 54, 55, 56, 59, 6, 60, 61, 65, 66, 67]

#################################################################

for e in range(16):
    #result.append("/Scr/arango/ergosterol-amb/dgx_runs/compound_screen/"+str(name)+".fep/run/f"+str(e)+"/f"+str(e)+".dcd")
    u = mda.Universe("/Scr/arango/ergosterol-amb/sponge_simulations/"+str(name)+"/1.psf", 
                 "/Scr/arango/ergosterol-amb/dgx_runs/compound_screen/"+str(name)+".fep/run/f"+str(e)+"/f"+str(e)+".dcd")
    psi_list1 = []
    psi_list2 = []
    psi_list3 = []
    for res in reslist:
        psi_anglex = u.atoms.select_atoms('resname AMB and resid '+str(res)+' and name C7 O5 C12 C15')
        psi_anglex = psi_anglex.dihedral # convert AtomGroup to Dihedral object
        psi_angley = u.select_atoms('resname AMB and resid '+str(res)+' and  name C7 O5 C12 C10')
        psi_angley = psi_angley.dihedral # convert AtomGroup to Dihedral object
        #psi_anglez = u.select_atoms('resname AMB and resid '+str(res)+' and  name C8 C6 C4 C2')
        #psi_anglez = psi_anglez.dihedral # convert AtomGroup to Dihedral object
        for ts in u.trajectory:
            psi_list1.append(dihe(psi_anglex))
            psi_list2.append(dihe(psi_angley))
            #psi_list3.append(dihe(psi_anglez))
        #print(psi_list)
    df1 = pd.DataFrame(psi_list1)
    df2 = pd.DataFrame(psi_list2)
    #df3 = pd.DataFrame(psi_list3)
    df1.to_csv('out1.'+str(name)+'.'+str(e)+'.csv')
    df2.to_csv('out2.'+str(name)+'.'+str(e)+'.csv')
    #with open(f"file3{name}.txt", "w") as output:
    #    output.write(psi_list3)

# %%
######################
######ERGOSTEROL PHI2#######
######################
import MDAnalysis as mda
from MDAnalysis.analysis.dihedrals import Dihedral
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import cm

name = "219.ERG"
def dihe(ag):
    a = ag.dihedral
    b = ag.value()
    return b
result = []
#reslist = [80, 51, 24, 120, 8, 121, 110, 74, 1, 116, 20, 47, 76, 77, 78, 79, 117, 21, 48, 49, 50, 118, 22, 119, 23]
reslist1 = [137, 82, 26, 220, 126, 70, 15, 209, 121, 4, 59, 115, 134, 80, 23, 218, 124, 67, 13, 206, 112, 57, 250, 99, 132, 78, 21, 216, 122, 65, 11, 187, 110, 55, 248, 77] 
reslist2 = [25, 81, 136, 191, 180, 125, 69, 14, 169, 114, 58, 3, 189, 133, 78, 22, 177, 123, 66, 12, 167, 111, 56, 249, 186, 131, 75, 20, 175, 120, 64, 9, 164, 109, 53, 247]
#################################################################

for e in range(16):
    #result.append("/Scr/arango/ergosterol-amb/dgx_runs/compound_screen/"+str(name)+".fep/run/f"+str(e)+"/f"+str(e)+".dcd")
    u = mda.Universe("/Scr/arango/ergosterol-amb/sponge_simulations/"+str(name)+"/1.psf", 
                 "/Scr/arango/ergosterol-amb/dgx_runs/compound_screen/"+str(name)+".fep/run/f"+str(e)+"/f"+str(e)+".dcd")
    psi_list1 = []
    psi_list2 = []
    psi_list3 = []
    for res in range(36):
        psi_anglex = u.atoms.select_atoms('resname CHL1 and resid '+str(reslist1[res])+' and name C17 C20 C22 C23')
        psi_anglex = psi_anglex.dihedral # convert AtomGroup to Dihedral object
        psi_angley = u.select_atoms('resname CHL1 and resid '+str(reslist2[res])+' and  name C17 C20 C22 C23')
        psi_angley = psi_angley.dihedral # convert AtomGroup to Dihedral object
        #psi_anglez = u.select_atoms('resname AMB and resid '+str(res)+' and  name C8 C6 C4 C2')
        #psi_anglez = psi_anglez.dihedral # convert AtomGroup to Dihedral object
        for ts in u.trajectory:
            psi_list1.append(dihe(psi_anglex))
            psi_list2.append(dihe(psi_angley))
            #psi_list3.append(dihe(psi_anglez))
        #print(psi_list)
    df1 = pd.DataFrame(psi_list1)
    df2 = pd.DataFrame(psi_list2)
    #df3 = pd.DataFrame(psi_list3)
    df1.to_csv('Phii1.'+str(name)+'.'+str(e)+'.csv')
    df2.to_csv('Phii2.'+str(name)+'.'+str(e)+'.csv')
    #with open(f"file3{name}.txt", "w") as output:
    #    output.write(psi_list3)

# %%
######################
######ERGOSTEROL EPI WATER#######
######################
import MDAnalysis as mda
from MDAnalysis.analysis.dihedrals import Dihedral
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import cm

name = "EPI.ONE"
def dihe(ag):
    a = ag.dihedral
    b = ag.value()
    return b
result = []
#reslist = [80, 51, 24, 120, 8, 121, 110, 74, 1, 116, 20, 47, 76, 77, 78, 79, 117, 21, 48, 49, 50, 118, 22, 119, 23]
#reslist1 = [137, 82, 26, 220, 126, 70, 15, 209, 121, 4, 59, 115, 134, 80, 23, 218, 124, 67, 13, 206, 112, 57, 250, 99, 132, 78, 21, 216, 122, 65, 11, 187, 110, 55, 248, 77] 
#reslist2 = [25, 81, 136, 191, 180, 125, 69, 14, 169, 114, 58, 3, 189, 133, 78, 22, 177, 123, 66, 12, 167, 111, 56, 249, 186, 131, 75, 20, 175, 120, 64, 9, 164, 109, 53, 247]
reslist = [33]
#################################################################

for e in range(16):
    #result.append("/Scr/arango/ergosterol-amb/dgx_runs/compound_screen/"+str(name)+".fep/run/f"+str(e)+"/f"+str(e)+".dcd")
    u = mda.Universe("/Scr/arango/ergosterol-amb/dgx_runs/setup_amb/EPI.WAT/1.psf", 
                 "/Scr/arango/ergosterol-amb/dgx_runs/"+str(name)+".fep/run/f"+str(e)+"/f"+str(e)+".dcd")
    psi_list1 = []
    psi_list2 = []
    psi_list3 = []
    for res in range(1):
        psi_anglex = u.atoms.select_atoms('resname AMB and resid '+str(reslist[0])+' and name C7 O5 C12 C15')
        psi_anglex = psi_anglex.dihedral # convert AtomGroup to Dihedral object
        psi_angley = u.select_atoms('resname AMB and resid '+str(reslist[0])+' and  name C7 O5 C12 C10')
        psi_angley = psi_angley.dihedral # convert AtomGroup to Dihedral object
        #psi_anglez = u.select_atoms('resname AMB and resid '+str(res)+' and  name C8 C6 C4 C2')
        #psi_anglez = psi_anglez.dihedral # convert AtomGroup to Dihedral object
        for ts in u.trajectory:
            psi_list1.append(dihe(psi_anglex))
            psi_list2.append(dihe(psi_angley))
            #psi_list3.append(dihe(psi_anglez))
        #print(psi_list)
    df1 = pd.DataFrame(psi_list1)
    df2 = pd.DataFrame(psi_list2)
    #df3 = pd.DataFrame(psi_list3)
    df1.to_csv('fuck1.'+str(name)+'.'+str(e)+'.csv')
    df2.to_csv('fuck2.'+str(name)+'.'+str(e)+'.csv')
    #with open(f"file3{name}.txt", "w") as output:
    #    output.write(psi_list3)

# %%
psi_list1 = []
psi_list2 = []
psi_list3 = []
for ts in u.trajectory:
    psi_list1.append(Dihe(psi_anglex))
    psi_list2.append(Dihe(psi_angley))
    psi_list3.append(Dihe(psi_anglez))
print(psi_list)

# %%
df1 = pd.DataFrame(psi_list1)
df2 = pd.DataFrame(psi_list2)
df3 = pd.DataFrame(psi_list3)
with open("file1"+str(name)+".txt", "w") as output:
    output.write(psi_list1)
with open("file2"+str(name)+".txt", "w") as output:
    output.write(psi_list2)
with open("file3"+str(name)+".txt", "w") as output:
    output.write(psi_list3)

# %%
len(df[0])
# Out:
# 33644

# %%
df1 = pd.read_csv('/Scr/arango/ergosterol-amb/dgx_runs/analysis/file1.txt', header=None)
df2 = pd.read_csv('/Scr/arango/ergosterol-amb/dgx_runs/analysis/file2.txt', header=None)
df3 = pd.read_csv('/Scr/arango/ergosterol-amb/dgx_runs/analysis/file3.txt', header=None)

# %%
from ast import literal_eval

f=open("/Scr/arango/ergosterol-amb/dgx_runs/analysis/file1.txt",'r')

for line in f:
    new_list = literal_eval(line)
f.close()

f=open("/Scr/arango/ergosterol-amb/dgx_runs/analysis/file2.txt",'r')

for line in f:
    new_list2 = literal_eval(line)
f.close()

f=open("/Scr/arango/ergosterol-amb/dgx_runs/analysis/file3.txt",'r')

for line in f:
    new_list3 = literal_eval(line)
f.close()

# %%
df1 = pd.DataFrame(new_list)
df2 = pd.DataFrame(new_list2)
df3 = pd.DataFrame(new_list3)

# %%
bataN = df1.T
bataM = bataN.assign(mean=bataN.mean(axis=1))

a = bataM[0:536817].values.ravel()
print(len(a))

dataN = df2.T
dataM = dataN.assign(mean=dataN.mean(axis=1))

b = dataM[0:536817].values.ravel()
print(len(b))

xataN = df3.T
xataM = xataN.assign(mean=xataN.mean(axis=1))

c = xataM[0:536817].values.ravel()
print(len(c))
# Out:
# 536817
# 536817
# 536817

# %%
a =a[::10]
b = b[::10] 
c = c[::10]

# %%
sns.distplot( x=a, hist=True, kde=True, rug=False, label="a" )
sns.distplot( x=b, hist=True, kde=True, rug=False, label="b")
sns.distplot( x=c, hist=True, kde=True, rug=False, label="c")
# Out:
# /Projects/arango/anaconda3/lib/python3.6/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /Projects/arango/anaconda3/lib/python3.6/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
print(b)
# Out:
# [117.07289402 108.77581422   8.31711907 ...  76.45518204  79.92989956
#   43.71235039]

# %%
plt.clf()
h = sns.jointplot(x=a, y=b, cmap=cm.nipy_spectral)
plt.gcf().suptitle('Probability Density of AmB Dihedrals', fontsize=18)
#plt.xlim(140, 240)
#plt.ylim(140, 240)
h.set_axis_labels('C19-O-C1′-C2′ (°)', 'C20-C19-O-C1′ (°)', fontsize=14)

# or set labels via the axes objects
plt.tight_layout()

# %%
plt.clf()
h = sns.jointplot(x=a, y=b, kind = 'kde', space=1, fill=True, thresh=0, cmap=cm.nipy_spectral)
plt.gcf().suptitle('Probability Density of AmB Dihedrals', fontsize=18)
#plt.xlim(140, 240)
#plt.ylim(140, 240)
h.set_axis_labels('C19-O-C1′-C2′ (°)', 'C20-C19-O-C1′ (°)', fontsize=14)

# or set labels via the axes objects
plt.tight_layout()

# %%
plt.clf()
h = sns.jointplot(x=a%360, y=b%360, kind = 'kde', space=1, fill=True, thresh=0.1, cmap=cm.nipy_spectral)
plt.gcf().suptitle('Probability Density of AmB Dihedrals', fontsize=18)
#plt.xlim(140, 240)
#plt.ylim(140, 240)
h.set_axis_labels('C19-O-C1′-C2′ (°)', 'C20-C19-O-C1′ (°)', fontsize=14)

# or set labels via the axes objects
plt.tight_layout()

# %%
import numpy as np
import math  as m
import matplotlib.pyplot as plt
import matplotlib as mpl
import numpy as np
from matplotlib import rc
import seaborn as sns
from matplotlib import cm 

rc('font',**{'family':'sans-serif','sans-serif':['Helvetica']})
rc('text', usetex=True)
mpl.rcParams['axes.linewidth'] = 2
mpl.rcParams.update({'figure.autolayout': True})
mpl.rcParams["text.usetex"] = False

bin_size = 20

T = []
X1 = []
X2 = []

hist,xedges,yedges = np.histogram2d(a, b, bins = bin_size,  range = ([0, 360], [0, 360]), density=True)

FE = np.zeros((bin_size, bin_size))

for i in range(0, bin_size):
	for j in range(0, bin_size):
		if hist[i][j] == 0:
			hist[i][j] = np.min(hist)
		FE[i][j] = -0.616 * np.log(hist[i][j])


min_FE = np.min(FE)

for i in range(0, bin_size):
 	for j in range(0, bin_size):
 		FE[i][j] = FE[i][j] - min_FE
range_bar = np.linspace(0,1.5,100)
# plt.contour(xedges[0:bin_size], yedges[0:bin_size], np.transpose(FE), 2, colors = 'dimgray', linewidths = 1)
plt.contourf(xedges[0:bin_size], yedges[0:bin_size], np.transpose(FE), levels = range_bar, cmap=plt.cm.nipy_spectral)

#plt.plot(215, 215, marker="o", markersize=10, markeredgecolor="black", markerfacecolor="pink")

#plt.plot(45, 215, marker="o", markersize=10, markeredgecolor="black", markerfacecolor="pink")
#plt.plot(135, 315, marker="o", markersize=10, markeredgecolor="black", markerfacecolor="magenta")

C = plt.colorbar()
plt.xlabel(r'a', fontsize = 20)
plt.ylabel(r'n', fontsize = 20)
plt.xticks(fontsize = 15)
plt.yticks(fontsize = 15)
plt.xlim((50,240))
plt.ylim((140,240))
#plt.xticks(np.arange(0, 361, 45))
#plt.yticks(np.arange(0, 361, 45))

C.set_label(r'Free energy (kcal/mol)', fontsize = 20)
C.ax.tick_params(labelsize=15)
C.set_ticks(np.arange(0, 1.6, 0.5))

#plt.savefig("FE-customized.pdf")

#for i in range(0, bin_size):
#	OUTPUT.write('{}    '.format(i))
#	OUTPUT.write('{}    '.format(xedges[i]))
#	OUTPUT.write('{}    '.format(yedges[i]))
#	OUTPUT.write('{}  \n'.format(FE[i]))
# Out:
# /Projects/arango/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:30: RuntimeWarning: divide by zero encountered in log

# %%
import numpy as np
import math  as m
import matplotlib.pyplot as plt
import matplotlib as mpl
import numpy as np
from matplotlib import rc
import seaborn as sns
from matplotlib import cm, colors
#from matplotlib import cm 

#rc('font',**{'family':'sans-serif','sans-serif':['Helvetica']})
#rc('text', usetex=True)
#mpl.rcParams['axes.linewidth'] = 2
#mpl.rcParams.update({'figure.autolayout': True})
mpl.rcParams["text.usetex"] = False

bin_size = 20

T = []
X1 = []
X2 = []

hist,xedges,yedges = np.histogram2d(a, b, bins = bin_size,  range = ([0, 360], [0, 360]), density=True)

FE = np.zeros((bin_size, bin_size))

for i in range(0, bin_size):
	for j in range(0, bin_size):
		if hist[i][j] == 0:
			hist[i][j] = np.min(hist)
		FE[i][j] = -0.616 * np.log(hist[i][j])
		print(np.log(hist[i][j]))


min_FE = np.min(FE)

for i in range(0, bin_size):
 	for j in range(0, bin_size):
 		FE[i][j] = FE[i][j] - min_FE
range_bar = np.linspace(0,1.5,100)
# plt.contour(xedges[0:bin_size], yedges[0:bin_size], np.transpose(FE), 2, colors = 'dimgray', linewidths = 1)
plt.clf()
h = sns.jointplot(a, b, np.transpose(FE), cmap=plt.cm.nipy_spectral)
plt.gcf().suptitle('Probability Density of AmB Dihedrals', fontsize=18)
#plt.xlim(140, 240)
#plt.ylim(140, 240)
h.set_axis_labels('C19-O-C1′-C2′ (°)', 'C20-C19-O-C1′ (°)', fontsize=14)

# or set labels via the axes objects
plt.tight_layout()
#plt.contourf(xedges[0:bin_size], yedges[0:bin_size], np.transpose(FE), levels = range_bar, cmap=plt.cm.nipy_spectral)

#plt.plot(215, 215, marker="o", markersize=10, markeredgecolor="black", markerfacecolor="pink")

#plt.plot(45, 215, marker="o", markersize=10, markeredgecolor="black", markerfacecolor="pink")
#plt.plot(135, 315, marker="o", markersize=10, markeredgecolor="black", markerfacecolor="magenta")

C = plt.colorbar(cm.ScalarMappable(norm=np.transpose(FE),cmap='YlGnBu'))
plt.xlabel(r'a', fontsize = 20)
plt.ylabel(r'n', fontsize = 20)
plt.xticks(fontsize = 15)
plt.yticks(fontsize = 15)
plt.xlim((50,240))
plt.ylim((140,240))
#plt.xticks(np.arange(0, 361, 45))
#plt.yticks(np.arange(0, 361, 45))

C.set_label(r'Free energy (kcal/mol)', fontsize = 20)
C.ax.tick_params(labelsize=15)
C.set_ticks(np.arange(0, 1.6, 0.5))

#plt.savefig("FE-customized.pdf")

#for i in range(0, bin_size):
#	OUTPUT.write('{}    '.format(i))
#	OUTPUT.write('{}    '.format(xedges[i]))
#	OUTPUT.write('{}    '.format(yedges[i]))
#	OUTPUT.write('{}  \n'.format(FE[i]))
# Out:
# /Projects/arango/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:31: RuntimeWarning: divide by zero encountered in log
# /Projects/arango/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:32: RuntimeWarning: divide by zero encountered in log
# /Projects/arango/anaconda3/lib/python3.6/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y, data. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# -inf
# ...

# %%
#plot
from matplotlib import cm, colors

fig,ax = plt.subplots(figsize=(9,6))  
#plt.clf()
h = sns.jointplot(x=a, y=b, np.transpose(FE), kind = 'kde', space=1, fill=True, thresh=0, cmap=cm.nipy_spectral)
plt.suptitle('Probability Density of AmB Dihedrals', fontsize=18)
#plt.xlim(140, 240)
#plt.ylim(140, 240)
h.set_axis_labels('C19-O-C1′-C2′ (°)', 'C20-C19-O-C1′ (°)', fontsize=14)

# or set labels via the axes objects
#plt.tight_layout()

norm = colors.Normalize(FE.min(), FE.max())
#plt.xticks(rotation=90)
fig.colorbar(cm.ScalarMappable(norm=norm,cmap=cm.nipy_spectral), ax=ax)


#plt.xticks(rotation=90)
#plt.colorbar()
plt.show()
plt.close()
# Out:
#   File "<ipython-input-144-116f72c747ba>", line 6
#     h = sns.jointplot(x=a, y=b, np.transpose(FE), kind = 'kde', space=1, fill=True, thresh=0, cmap=cm.nipy_spectral)
#                                ^
# SyntaxError: positional argument follows keyword argument

# %%
print(a)
# Out:
# [ 74.95585136 136.90612432 100.229338   ... 138.34019476 148.61024959
#  163.7249149 ]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

x = np.random.normal(loc=0, scale=1, size=1000)
y = np.random.normal(loc=0, scale=1, size=1000)
z = x**2  + y**2


plt.figure(num=1, figsize=(8, 5))
g = sns.jointplot(x=a, y=b, c=np.transpose(FE), joint_kws={"color":None, 'cmap':'viridis'})
g.fig.colorbar(g.ax_joint.collections[0], ax=[g.ax_joint, g.ax_marg_y, g.ax_marg_x], use_gridspec=True, orientation='horizontal')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /Projects/arango/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py in _parse_scatter_color_args(c, edgecolors, kwargs, xshape, yshape, get_next_color_func)
#    4283             try:  # Then is 'c' acceptable as PathCollection facecolors?
# -> 4284                 colors = mcolors.to_rgba_array(c)
#    4285                 n_elem = colors.shape[0]
#
# /Projects/arango/anaconda3/lib/python3.6/site-packages/matplotlib/colors.py in to_rgba_array(c, alpha)
#     293     for i, cc in enumerate(c):
# --> 294         result[i] = to_rgba(cc, alpha)
#     295     return result
#
# /Projects/arango/anaconda3/lib/python3.6/site-packages/matplotlib/colors.py in to_rgba(c, alpha)
#     176     if rgba is None:  # Suppress exception chaining of cache lookup failure.
# --> 177         rgba = _to_rgba_no_colorcycle(c, alpha)
# ...
